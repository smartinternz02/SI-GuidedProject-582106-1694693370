# %% [markdown]
# # **TASK 3 Evening Slot**
# ###08-09-2023 ( Friday )
# By : Madhav ( 21BCE3239 )
# madhavkumar.chaudhary2021@vitstudent.ac.in

# %% [markdown]
# ### **importing required libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ---
# ### **Download the dataset .**
# ### **Load the dataset into the tool.**
# ---

# %%
# loading the downloaded dataset
df=pd.read_csv('/content/penguins_size.csv')
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %% [markdown]
# checking the loaded data

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
df.tail()
# Out:
#     species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 339  Gentoo  Biscoe               NaN              NaN                NaN
# 340  Gentoo  Biscoe              46.8             14.3              215.0
# 341  Gentoo  Biscoe              50.4             15.7              222.0
# 342  Gentoo  Biscoe              45.2             14.8              212.0
# 343  Gentoo  Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# 339          NaN     NaN
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE

# %%
df.shape
# Out:
# (344, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# ---
# ###**Perform descriptive statistics on the dataset.**
# ---

# %%
df.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %%
# checking count of categorical parameters

# %%
df.species.value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
df.island.value_counts()
# Out:
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: island, dtype: int64

# %%
df.sex.value_counts()
# Out:
# MALE      168
# FEMALE    165
# .           1
# Name: sex, dtype: int64

# %%
df.corr()
# Out:
# <ipython-input-163-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# culmen_length_mm           1.000000        -0.235053           0.656181
# culmen_depth_mm           -0.235053         1.000000          -0.583851
# flipper_length_mm          0.656181        -0.583851           1.000000
# body_mass_g                0.595110        -0.471916           0.871202
#
#                    body_mass_g
# culmen_length_mm      0.595110
# culmen_depth_mm      -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %% [markdown]
# ---
# ###**Check for Missing values and deal with them.**
# ---

# %%
df['sex']=df['sex'].replace(".","MALE")

# %%
df.sex.value_counts()
# Out:
# MALE      169
# FEMALE    165
# Name: sex, dtype: int64

# %%
df.isnull().any()
# Out:
# species              False
# island               False
# culmen_length_mm      True
# culmen_depth_mm       True
# flipper_length_mm     True
# body_mass_g           True
# sex                   True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
df.median()
# Out:
# <ipython-input-168-6d467abf240d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# culmen_length_mm       44.45
# culmen_depth_mm        17.30
# flipper_length_mm     197.00
# body_mass_g          4050.00
# dtype: float64

# %%
#  null values of categorical parameters, replacing it with mode
df['sex']=df['sex'].fillna("MALE")

# %%
df=df.fillna(df.median())
# Out:
# <ipython-input-170-42d29455c84b>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df=df.fillna(df.median())

# %%
#  null values of numerical parameters, replacing it with median
df['culmen_length_mm'].fillna(df['culmen_length_mm'].median(),inplace =True)
df['culmen_depth_mm'].fillna(df['culmen_depth_mm'].median(),inplace =True)
df['flipper_length_mm'].fillna(df['flipper_length_mm'].median(),inplace =True)
df['body_mass_g'].fillna(df['body_mass_g'].median(),inplace =True)

# %%
df.isnull().any()
# Out:
# species              False
# island               False
# culmen_length_mm     False
# culmen_depth_mm      False
# flipper_length_mm    False
# body_mass_g          False
# sex                  False
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   344 non-null    float64
#  3   culmen_depth_mm    344 non-null    float64
#  4   flipper_length_mm  344 non-null    float64
#  5   body_mass_g        344 non-null    float64
#  6   sex                344 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# ---
# **Perform Below Visualizations.**
# ---

# %% [markdown]
# ● Univariate Analysis

# %%
sns.distplot(df.culmen_length_mm)
# Out:
# <ipython-input-174-24e9b5890c61>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.culmen_length_mm)
# <Axes: xlabel='culmen_length_mm', ylabel='Density'>

# %%
sns.distplot(df.culmen_depth_mm)
# Out:
# <ipython-input-175-4b07ffb4fe44>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.culmen_depth_mm)
# <Axes: xlabel='culmen_depth_mm', ylabel='Density'>

# %%
sns.distplot(df.flipper_length_mm)
# Out:
# <ipython-input-176-4c42e92ff055>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.flipper_length_mm)
# <Axes: xlabel='flipper_length_mm', ylabel='Density'>

# %%
sns.distplot(df.body_mass_g)
# Out:
# <ipython-input-177-176964dae727>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.body_mass_g)
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %%
#for categorical pie chart
plt.pie(df.species.value_counts(),[0,0.1,0],labels = ['Adelie','Gentoo','Chinstrap'],autopct ='%1.1f%%',shadow = True,colors = ['purple','yellow','red'],)
plt.title('SPECIES')
plt.show()

# %%
plt.pie(df.island.value_counts(),[0.08,0.1,0.08],labels = ['Biscoe','Dream','Torgersen'],autopct ='%1.1f%%',shadow = True,colors = ['green','yellow','red'],)
plt.title('ISLAND')
plt.show()

# %%
#for categorical pie chart
plt.pie(df.sex.value_counts(),[0,0.1],labels = ['MALE','FEMALE'],autopct ='%1.1f%%',shadow = True,colors = ['BLUE','yellow'],)
plt.title('SMOKER')
plt.show()

# %%
sns.barplot(x =df.island.value_counts().index,y =df.island.value_counts() )
# Out:
# <Axes: ylabel='island'>

# %%
sns.barplot(x =df.species.value_counts().index,y =df.species.value_counts() )
# Out:
# <Axes: ylabel='species'>

# %%
sns.barplot(x =df.sex.value_counts().index,y =df.sex.value_counts() )
# Out:
# <Axes: ylabel='sex'>

# %%
sns.catplot(data=df,x='species',kind="count",palette="ch:.75")
plt.title('species')
# Out:
# Text(0.5, 1.0, 'species')

# %% [markdown]
# ● Bivariate Analysis

# %%
sns.lineplot(x = df.culmen_length_mm ,y=df.culmen_depth_mm )
# Out:
# <Axes: xlabel='culmen_length_mm', ylabel='culmen_depth_mm'>

# %%
sns.lineplot(x = df.culmen_length_mm ,y=df.flipper_length_mm )
# Out:
# <Axes: xlabel='culmen_length_mm', ylabel='flipper_length_mm'>

# %%
sns.scatterplot(x = df.body_mass_g,y=df.culmen_depth_mm)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='culmen_depth_mm'>

# %% [markdown]
# ● Multivariate Analysis

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <ipython-input-189-8df7bcac526d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %% [markdown]
# ---
# ##**Find the outliers and replace them outliers**
# ---

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen             39.10             18.7              181.0
# 1  Adelie  Torgersen             39.50             17.4              186.0
# 2  Adelie  Torgersen             40.30             18.0              195.0
# 3  Adelie  Torgersen             44.45             17.3              197.0
# 4  Adelie  Torgersen             36.70             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3       4050.0    MALE
# 4       3450.0  FEMALE

# %%
sns.boxplot(df.culmen_length_mm)
# Out:
# <Axes: >

# %%
sns.boxplot(df.culmen_depth_mm)
# Out:
# <Axes: >

# %%
sns.boxplot(df.flipper_length_mm)
# Out:
# <Axes: >

# %%
sns.boxplot(df.body_mass_g)
# Out:
# <Axes: >

# %% [markdown]
# so as we can see there are no outlayers in any of the parameters ..

# %%
#df.corr().species.sort_values(ascending =False)

# %% [markdown]
# ---
# ## **Check for Categorical columns and perform encoding.**
# ---

# %% [markdown]
# label encoding for sex column

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df.sex = le.fit_transform(df.sex)

# %% [markdown]
# label encoding for species column

# %%
df.species = le.fit_transform(df.species)

# %% [markdown]
# label encoding for species column

# %%
df.island = le.fit_transform(df.island)

# %%
df.head()
# Out:
#    species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0        0       2             39.10             18.7              181.0
# 1        0       2             39.50             17.4              186.0
# 2        0       2             40.30             18.0              195.0
# 3        0       2             44.45             17.3              197.0
# 4        0       2             36.70             19.3              193.0
#
#    body_mass_g  sex
# 0       3750.0    1
# 1       3800.0    0
# 2       3250.0    0
# 3       4050.0    1
# 4       3450.0    0

# %% [markdown]
# ---
# ##**Check the correlation of independent variables with the target**
# ---

# %%
df.corr()
# Out:
#                     species    island  culmen_length_mm  culmen_depth_mm  \
# species            1.000000 -0.635659          0.728706        -0.741282
# island            -0.635659  1.000000         -0.351189         0.567701
# culmen_length_mm   0.728706 -0.351189          1.000000        -0.235000
# culmen_depth_mm   -0.741282  0.567701         -0.235000         1.000000
# flipper_length_mm  0.850819 -0.562957          0.655858        -0.583832
# body_mass_g        0.747547 -0.558500          0.594925        -0.471942
# sex                0.010240  0.002893          0.322871         0.354791
#
#                    flipper_length_mm  body_mass_g       sex
# species                     0.850819     0.747547  0.010240
# island                     -0.562957    -0.558500  0.002893
# culmen_length_mm            0.655858     0.594925  0.322871
# culmen_depth_mm            -0.583832    -0.471942  0.354791
# flipper_length_mm           1.000000     0.871221  0.241941
# ...

# %%
plt.figure(figsize=(10,8)) # size of graph using figsize
sns.heatmap(df.corr(),annot =True)
# Out:
# <Axes: >

# %%
df.corr().species.sort_values(ascending =False)
# Out:
# species              1.000000
# flipper_length_mm    0.850819
# body_mass_g          0.747547
# culmen_length_mm     0.728706
# sex                  0.010240
# island              -0.635659
# culmen_depth_mm     -0.741282
# Name: species, dtype: float64

# %% [markdown]
# ---
# ## **Split the data into dependent and independent variables.**
# ---

# %%
y = df['species']
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 339    2
# 340    2
# 341    2
# 342    2
# 343    2
# Name: species, Length: 344, dtype: int64

# %%
X =df.drop(columns =['species'],axis =1)
X
# Out:
#      island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0         2             39.10             18.7              181.0
# 1         2             39.50             17.4              186.0
# 2         2             40.30             18.0              195.0
# 3         2             44.45             17.3              197.0
# 4         2             36.70             19.3              193.0
# ..      ...               ...              ...                ...
# 339       0             44.45             17.3              197.0
# 340       0             46.80             14.3              215.0
# 341       0             50.40             15.7              222.0
# 342       0             45.20             14.8              212.0
# 343       0             49.90             16.1              213.0
#
#      body_mass_g  sex
# 0         3750.0    1
# 1         3800.0    0
# 2         3250.0    0
# 3         4050.0    1
# 4         3450.0    0
# ..           ...  ...
# ...

# %% [markdown]
# ---
# ## **Scaling the data**
# ---

# %%
from sklearn.preprocessing import MinMaxScaler # import
scale =MinMaxScaler() #initialisation

# %%
X_scaled= pd.DataFrame(scale.fit_transform(X),columns =X.columns)

# %%
X_scaled.head()
# Out:
#    island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0     1.0          0.254545         0.666667           0.152542     0.291667
# 1     1.0          0.269091         0.511905           0.237288     0.305556
# 2     1.0          0.298182         0.583333           0.389831     0.152778
# 3     1.0          0.449091         0.500000           0.423729     0.375000
# 4     1.0          0.167273         0.738095           0.355932     0.208333
#
#    sex
# 0  1.0
# 1  0.0
# 2  0.0
# 3  1.0
# 4  0.0

# %% [markdown]
# ---
# ## **Split the data into training and testing**
# ---

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,test_size=0.3,random_state=10)

# %%
X_train.head()
# Out:
#      island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 258     0.0          0.432727         0.059524           0.610169
# 332     0.0          0.414545         0.250000           0.694915
# 121     1.0          0.203636         0.797619           0.440678
# 61      0.0          0.334545         0.952381           0.389831
# 70      1.0          0.050909         0.702381           0.305085
#
#      body_mass_g  sex
# 258     0.458333  0.0
# 332     0.541667  0.0
# 121     0.222222  1.0
# 61      0.472222  1.0
# 70      0.250000  0.0

# %%
y_train.head()
# Out:
# 258    2
# 332    2
# 121    0
# 61     0
# 70     0
# Name: species, dtype: int64

# %%
X_test.head()
# Out:
#      island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 229     0.0          0.534545         0.273810           0.728814
# 80      1.0          0.090909         0.488095           0.288136
# 327     0.0          0.774545         0.321429           0.796610
# 6       1.0          0.247273         0.559524           0.152542
# 309     0.0          0.727273         0.464286           0.983051
#
#      body_mass_g  sex
# 229     0.680556  1.0
# 80      0.138889  0.0
# 327     0.777778  1.0
# 6       0.256944  0.0
# 309     0.791667  1.0

# %%
y_test.head()
# Out:
# 229    2
# 80     0
# 327    2
# 6      0
# 309    2
# Name: species, dtype: int64

# %% [markdown]
# ---
# ## **check the training and testing data shape.**
# ---

# %%
y_train.shape
# Out:
# (240,)

# %%
X_test.shape
# Out:
# (104, 6)

# %%
X_train.shape
# Out:
# (240, 6)

# %%
y_test.shape
# Out:
# (104,)

# %% [markdown]
# ##  COMPLETED !!
